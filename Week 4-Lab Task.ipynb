# %% [markdown]
# # Introduction to Machine Learning and Toolkit Exercises

# %% [markdown]
# ## Introduction
#
# We will be using the iris data set for this tutorial. This is a well-known data set containing iris species and sepal and petal measurements. The data we will use are in a file called `Iris_Data.csv` found in the [data](../../data) directory.

# %%
#pip install pandas

# %%
from __future__ import print_function
from pandas import read_csv
import os
import pandas as pd

# %% [markdown]
# ## Question 1
#
# Load the data from the file using the techniques learned today. Examine it.
#
# Determine the following:
#
# * The number of data points (rows). (*Hint:* check out the dataframe `.shape` attribute.)
# * The column names. (*Hint:* check out the dataframe `.columns` attribute.)
# * The data types for each column. (*Hint:* check out the dataframe `.dtypes` attribute.)

# %%
#Download the dataset and store the dataset inside a folder named 'data'. 
#The folder 'data' should be created where your ipynb file stored in your computer.
dataset = os.sep.join(['data'] + ['Iris_dataset.csv'])  #we set up the path here
#now, just read the data using read_csv and print

##Write your code
data = pd.read_csv(dataset)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
##Write your code
rows = data.shape
rows
# Out:
# (150, 5)

# %%
##Write your code
column_name = data.columns
column_name
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
##Write your code
data_type = data.dtypes
data_type
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# ## Question 2
#
# Examine the species names and note that they all begin with 'Iris-'. Remove this portion of the name so the species name is shorter.
#
# *Hint:* there are multiple ways to do this, but you could use either the [string processing methods](http://pandas.pydata.org/pandas-docs/stable/text.html) or the [apply method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.apply.html).

# %%
##Write your code
data['species'] = data['species'].str.replace('Iris-','')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Question 3
#
# Determine the following:
# * The number of each species present. (*Hint:* check out the series `.value_counts` method.)
# * The mean, count, max, std, min, etc using describe function.

# %%
##Write your code
index = data[['species']]
index = index.value_counts()
index
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Question 4
#
# Calculate the following **for each species** in a separate dataframe:
#
# * The mean of each measurement (sepal_length, sepal_width, petal_length, and petal_width).
# * The median of each of these measurements.
#
# *Hint:* you may want to use Pandas [`groupby` method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html) to group by species before calculating the statistic.
#
# If you finish both of these, try calculating both statistics (mean and median) in a single table (i.e. with a single groupby call). See the section of the Pandas documentation on [applying multiple functions at once](http://pandas.pydata.org/pandas-docs/stable/groupby.html#applying-multiple-functions-at-once) for a hint.

# %%
##Write your code
data.groupby('species').agg(['mean','median'])
# Out:
#            sepal_length        sepal_width        petal_length         \
#                    mean median        mean median         mean median
# species
# setosa            5.006    5.0       3.418    3.4        1.464   1.50
# versicolor        5.936    5.9       2.770    2.8        4.260   4.35
# virginica         6.588    6.5       2.974    3.0        5.552   5.55
#
#            petal_width
#                   mean median
# species
# setosa           0.244    0.2
# versicolor       1.326    1.3
# virginica        2.026    2.0

# %% [markdown]
# ## Question 5
#
# Make a scatter plot of `sepal_length` vs `sepal_width` using Matplotlib. Label the axes and give the plot a title.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import matplotlib.pyplot as plt
# %matplotlib inline

##Write your code
import matplotlib.pyplot as plt

# plotting a bar graph
ax = plt.axes()
ax.scatter(data.sepal_length,data.sepal_width)

ax.set(xlabel = 'Sepel Length', ylabel = 'Sepal Width',title = 'Point Graph');

# %%
data.plot(x = "sepal_length", y = "sepal_width", kind="line")
# Out:
# <Axes: xlabel='sepal_length'>

# %% [markdown]
# ## Question 6
#
# Make a histogram of any one of the four features. Label axes and title it as appropriate.

# %%
##Write your code
plot2 = plt.axes()
plot2.hist(data.sepal_length, bins = 25);
plot2.set(xlabel = 'Length', ylabel = 'Number', title = 'Sepal_Length');

# %%
data.hist(column = 'sepal_length')
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>]], dtype=object)

# %% [markdown]
# ## Question 7
#
# Now create a single plot with histograms for each feature (`petal_width`, `petal_length`, `sepal_width`, `sepal_length`) overlayed.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
sns.set_context('notebook')

##Write your code here


plot3 = data.plot.hist(bins = 25, alpha = 0.5)
plot3.set_xlabel('Size (cm)');

plot3List = data.hist(bins = 25);

#set plot title
#plt.title('Histograms for all features ') 
#set x (x-axis) and y (y-axis) labels
#plot3.set_xlabel('Size');
#plot3.set_ylabel('Frequency');

# %%
data.plot(kind = 'hist', title = 'Histogram')
# Out:
# <Axes: title={'center': 'Histogram'}, ylabel='Frequency'>

# %% [markdown]
# ## Question 8
#
# Make a [pairplot](http://seaborn.pydata.org/generated/seaborn.pairplot.html) with Seaborn to examine the correlation between each of the measurements.
#
# *Hint:* this plot may look complicated, but it is actually only a single line of code. This is the power of Seaborn and dataframe-aware plotting! See the lecture notes for reference.

# %%
##Write your code
sns.pairplot(data, hue = 'species');
# Out:
# /opt/Anaconda3-2023.03/envs/siu855784255@ad.siu.edu/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/Anaconda3-2023.03/envs/siu855784255@ad.siu.edu/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/Anaconda3-2023.03/envs/siu855784255@ad.siu.edu/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
